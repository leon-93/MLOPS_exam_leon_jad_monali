# %%
import pandas as pd
data=pd.read_csv("dpe-v2-logements-neufs.csv")
data
# Out:
# C:\Users\leonm\AppData\Local\Temp\ipykernel_16704\706675065.py:2: DtypeWarning: Columns (11,26,101,111,142,143,217,218) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("dpe-v2-logements-neufs.csv")
#                 N°DPE Date_réception_DPE Date_établissement_DPE  \
# 0       2133N0419762I         2021-09-30             2021-09-29
# 1       2262N1677399D         2022-07-22             2022-07-20
# 2       2333N0960129T         2023-03-22             2023-03-21
# 3       2474N0961053X         2024-03-16             2024-03-15
# 4       2317N4122363N         2023-12-01             2023-11-11
# ...               ...                ...                    ...
# 783111  2213N2868157Q         2022-11-29             2022-11-28
# 783112  2283N0914775G         2022-04-29             2022-04-28
# 783113  2272N1131209F         2022-05-23             2022-05-22
# 783114  2268N1454352Q         2022-06-28             2022-04-18
# ...
